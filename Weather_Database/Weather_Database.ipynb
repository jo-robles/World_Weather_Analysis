# %%
#Importing dependencies

import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Adding the latitudes and longitudes to a list. 

coordinates = list(lat_lngs)

# %%
#Use the citypy module to determine city based on latitude and longitude.

from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 787

# %%
#Importing the requests library. 
import requests

#Importing the API key. 
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data. 

city_data = []

#Print the beginning of the logging. 
print('Beginning Data Retrieval     ')
print('-----------------------------')

#Create counters. 
record_count = 1 
set_count = 1

#Looping through all the cities in our list. 

for i,city in enumerate(cities):

    #Group cities in sets of 50 for logging purposes. 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city. 
    city_url = url + '&q=' + city.replace(' ','+')

    #Log the URL, record, and set numbers and the city. 
    print(f'Processing Record {record_count} of Set {set_count} | {city}')

    #Add 1 to the record count. 
    record_count += 1

    #Run an API 

    try:
        #Parse the JSON and retrieve data. 
        city_weather = requests.get(city_url).json()
        #Parse out the needed data. 
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather ['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        #Append the city information into the city_data list. 
        city_data.append({"City": city.title(),
                        "Country": city_country,
                        "Lat": city_lat, 
                        "Lng": city_lng, 
                        "Max Temp": city_max_temp, 
                        "Humidity": city_humidity, 
                        "Cloudiness": city_clouds, 
                        "Wind Speed": city_wind,
                        "Current Description": city_description})
        #If an error is experienced, skip the city
    except:
        print('City not found. Skipping...')
        pass

#Indicate the Data loading is complete
print('---------------------------')
print('Data Retrieval Complete    ')
print('---------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | comodoro rivadavia
# Processing Record 2 of Set 1 | auki
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | morehead
# Processing Record 5 of Set 1 | hervey bay
# Processing Record 6 of Set 1 | butaritari
# Processing Record 7 of Set 1 | sitka
# Processing Record 8 of Set 1 | idrinskoye
# Processing Record 9 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 1 | dikson
# Processing Record 11 of Set 1 | longyearbyen
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | donnacona
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | aksu
# Processing Record 18 of Set 1 | san ramon
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | lujan
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | saskylakh
# Processing Record 23 of Set 1 | liberal
# Processing Record 24 of Set 1 | hithadhoo
# Processing Record 25 of Set 1 | adrar
# Processing Record 26 of Set 1 | viedma
# Processing Record 27 of Set 1 | onega
# Processing Record 28 of Set 1 | pundaguitan
# Processing Record 29 of Set 1 | makakilo city
# Processing Record 30 of Set 1 | brownsville
# Processing Record 31 of Set 1 | barinitas
# Processing Record 32 of Set 1 | clyde river
# Processing Record 33 of Set 1 | noumea
# Processing Record 34 of Set 1 | puerto colombia
# Processing Record 35 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 1 | romny
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | provideniya
# Processing Record 39 of Set 1 | punta arenas
# Processing Record 40 of Set 1 | east london
# Processing Record 41 of Set 1 | chuy
# Processing Record 42 of Set 1 | aguadilla
# Processing Record 43 of Set 1 | castro
# Processing Record 44 of Set 1 | mahebourg
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 1 | kontagora
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | genthin
# Processing Record 50 of Set 1 | labuhan
# Processing Record 1 of Set 2 | cozieni
# Processing Record 2 of Set 2 | ushuaia
# Processing Record 3 of Set 2 | bluff
# Processing Record 4 of Set 2 | constitucion
# Processing Record 5 of Set 2 | birao
# Processing Record 6 of Set 2 | sinkat
# City not found. Skipping...
# Processing Record 7 of Set 2 | port-gentil
# Processing Record 8 of Set 2 | lompoc
# Processing Record 9 of Set 2 | brae
# Processing Record 10 of Set 2 | mataura
# Processing Record 11 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 2 | general cepeda
# Processing Record 13 of Set 2 | merauke
# Processing Record 14 of Set 2 | mehamn
# Processing Record 15 of Set 2 | xuddur
# Processing Record 16 of Set 2 | komsomolskiy
# Processing Record 17 of Set 2 | biak
# Processing Record 18 of Set 2 | sistranda
# Processing Record 19 of Set 2 | upernavik
# Processing Record 20 of Set 2 | bengkulu
# Processing Record 21 of Set 2 | severo-kurilsk
# Processing Record 22 of Set 2 | albany
# Processing Record 23 of Set 2 | wahpeton
# Processing Record 24 of Set 2 | asau
# Processing Record 25 of Set 2 | san cristobal
# Processing Record 26 of Set 2 | yellowknife
# Processing Record 27 of Set 2 | lavrentiya
# Processing Record 28 of Set 2 | ugoofaaru
# Processing Record 29 of Set 2 | saint-francois
# Processing Record 30 of Set 2 | havelock
# Processing Record 31 of Set 2 | kahului
# Processing Record 32 of Set 2 | victoria
# Processing Record 33 of Set 2 | valley
# Processing Record 34 of Set 2 | chokurdakh
# Processing Record 35 of Set 2 | rochegda
# Processing Record 36 of Set 2 | fortuna
# Processing Record 37 of Set 2 | batemans bay
# Processing Record 38 of Set 2 | wladyslawowo
# Processing Record 39 of Set 2 | pandan
# Processing Record 40 of Set 2 | esterhazy
# Processing Record 41 of Set 2 | ye
# City not found. Skipping...
# Processing Record 42 of Set 2 | campbell river
# Processing Record 43 of Set 2 | mount gambier
# Processing Record 44 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 2 | pedasi
# Processing Record 46 of Set 2 | zunyi
# Processing Record 47 of Set 2 | faanui
# Processing Record 48 of Set 2 | port hedland
# Processing Record 49 of Set 2 | fairbanks
# Processing Record 50 of Set 2 | nanortalik
# Processing Record 1 of Set 3 | barrow
# Processing Record 2 of Set 3 | kruisfontein
# Processing Record 3 of Set 3 | saint george
# Processing Record 4 of Set 3 | anadyr
# Processing Record 5 of Set 3 | cabedelo
# Processing Record 6 of Set 3 | santa isabel do rio negro
# Processing Record 7 of Set 3 | san quintin
# Processing Record 8 of Set 3 | ola
# Processing Record 9 of Set 3 | kyshtovka
# Processing Record 10 of Set 3 | tombouctou
# Processing Record 11 of Set 3 | maldonado
# Processing Record 12 of Set 3 | vaini
# Processing Record 13 of Set 3 | hermanus
# Processing Record 14 of Set 3 | kapaa
# Processing Record 15 of Set 3 | pacific grove
# Processing Record 16 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 17 of Set 3 | arraial do cabo
# Processing Record 18 of Set 3 | kitimat
# Processing Record 19 of Set 3 | carauari
# Processing Record 20 of Set 3 | palmer
# Processing Record 21 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 3 | kutum
# Processing Record 23 of Set 3 | lebu
# Processing Record 24 of Set 3 | bonavista
# Processing Record 25 of Set 3 | tuktoyaktuk
# Processing Record 26 of Set 3 | bjorkelangen
# Processing Record 27 of Set 3 | farafangana
# Processing Record 28 of Set 3 | shakhtinsk
# Processing Record 29 of Set 3 | nueva loja
# Processing Record 30 of Set 3 | paamiut
# Processing Record 31 of Set 3 | geraldton
# Processing Record 32 of Set 3 | mashhad
# Processing Record 33 of Set 3 | airai
# Processing Record 34 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 35 of Set 3 | karema
# Processing Record 36 of Set 3 | kushmurun
# Processing Record 37 of Set 3 | khatanga
# Processing Record 38 of Set 3 | gap
# Processing Record 39 of Set 3 | makrikapa
# City not found. Skipping...
# Processing Record 40 of Set 3 | husavik
# Processing Record 41 of Set 3 | taitung
# Processing Record 42 of Set 3 | sao filipe
# Processing Record 43 of Set 3 | nikolskoye
# Processing Record 44 of Set 3 | saint-denis
# Processing Record 45 of Set 3 | tiksi
# Processing Record 46 of Set 3 | avera
# Processing Record 47 of Set 3 | leshukonskoye
# Processing Record 48 of Set 3 | rabo de peixe
# Processing Record 49 of Set 3 | aritao
# Processing Record 50 of Set 3 | champasak
# Processing Record 1 of Set 4 | bontang
# Processing Record 2 of Set 4 | ilhabela
# Processing Record 3 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 4 | golub-dobrzyn
# Processing Record 5 of Set 4 | saint anthony
# Processing Record 6 of Set 4 | saurimo
# Processing Record 7 of Set 4 | nome
# Processing Record 8 of Set 4 | thompson
# Processing Record 9 of Set 4 | flinders
# Processing Record 10 of Set 4 | dunedin
# Processing Record 11 of Set 4 | deshna
# City not found. Skipping...
# Processing Record 12 of Set 4 | diamantino
# Processing Record 13 of Set 4 | clarksburg
# Processing Record 14 of Set 4 | bubaque
# Processing Record 15 of Set 4 | ixtapa
# Processing Record 16 of Set 4 | havre
# Processing Record 17 of Set 4 | kavieng
# Processing Record 18 of Set 4 | warmbad
# Processing Record 19 of Set 4 | golden rock
# City not found. Skipping...
# Processing Record 20 of Set 4 | raga
# Processing Record 21 of Set 4 | bambous virieux
# Processing Record 22 of Set 4 | yatou
# Processing Record 23 of Set 4 | zaranj
# Processing Record 24 of Set 4 | vila velha
# Processing Record 25 of Set 4 | ilinskiy
# Processing Record 26 of Set 4 | marawi
# Processing Record 27 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 4 | araguaina
# Processing Record 30 of Set 4 | hinatuan
# Processing Record 31 of Set 4 | kedrovyy
# Processing Record 32 of Set 4 | roald
# Processing Record 33 of Set 4 | burica
# City not found. Skipping...
# Processing Record 34 of Set 4 | formoso do araguaia
# City not found. Skipping...
# Processing Record 35 of Set 4 | bellevue
# Processing Record 36 of Set 4 | saint-philippe
# Processing Record 37 of Set 4 | port hawkesbury
# Processing Record 38 of Set 4 | lata
# Processing Record 39 of Set 4 | carnarvon
# Processing Record 40 of Set 4 | conceicao do mato dentro
# Processing Record 41 of Set 4 | pekin
# Processing Record 42 of Set 4 | cherskiy
# Processing Record 43 of Set 4 | cervo
# Processing Record 44 of Set 4 | cascais
# Processing Record 45 of Set 4 | emerald
# Processing Record 46 of Set 4 | trairi
# Processing Record 47 of Set 4 | coihaique
# Processing Record 48 of Set 4 | kaitangata
# Processing Record 49 of Set 4 | port macquarie
# Processing Record 50 of Set 4 | lamu
# Processing Record 1 of Set 5 | maningrida
# Processing Record 2 of Set 5 | ribeira grande
# Processing Record 3 of Set 5 | bathsheba
# Processing Record 4 of Set 5 | nueve de julio
# Processing Record 5 of Set 5 | tasiilaq
# Processing Record 6 of Set 5 | tautira
# Processing Record 7 of Set 5 | sukumo
# Processing Record 8 of Set 5 | esperance
# Processing Record 9 of Set 5 | nara
# Processing Record 10 of Set 5 | sorong
# Processing Record 11 of Set 5 | lapeer
# Processing Record 12 of Set 5 | urumqi
# Processing Record 13 of Set 5 | bambanglipuro
# Processing Record 14 of Set 5 | telde
# Processing Record 15 of Set 5 | kiunga
# Processing Record 16 of Set 5 | luderitz
# Processing Record 17 of Set 5 | wuwei
# Processing Record 18 of Set 5 | qaanaaq
# Processing Record 19 of Set 5 | torbay
# Processing Record 20 of Set 5 | oranjemund
# Processing Record 21 of Set 5 | lorengau
# Processing Record 22 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 5 | samarai
# Processing Record 24 of Set 5 | bianzhuang
# Processing Record 25 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 26 of Set 5 | pingzhuang
# Processing Record 27 of Set 5 | elizabeth city
# Processing Record 28 of Set 5 | necochea
# Processing Record 29 of Set 5 | bure
# Processing Record 30 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 5 | amahai
# Processing Record 32 of Set 5 | trinidad
# Processing Record 33 of Set 5 | avarua
# Processing Record 34 of Set 5 | shakiso
# Processing Record 35 of Set 5 | viseu
# Processing Record 36 of Set 5 | inuvik
# Processing Record 37 of Set 5 | komsomolets
# Processing Record 38 of Set 5 | port elizabeth
# Processing Record 39 of Set 5 | saldanha
# Processing Record 40 of Set 5 | chaihe
# Processing Record 41 of Set 5 | grenville
# Processing Record 42 of Set 5 | udachnyy
# Processing Record 43 of Set 5 | salinas
# Processing Record 44 of Set 5 | mareeba
# Processing Record 45 of Set 5 | mindelo
# Processing Record 46 of Set 5 | alofi
# Processing Record 47 of Set 5 | nuqui
# Processing Record 48 of Set 5 | grindavik
# Processing Record 49 of Set 5 | kalanaur
# Processing Record 50 of Set 5 | asfi
# Processing Record 1 of Set 6 | aitape
# Processing Record 2 of Set 6 | san carlos de bariloche
# Processing Record 3 of Set 6 | new norfolk
# Processing Record 4 of Set 6 | eyl
# Processing Record 5 of Set 6 | ilam
# Processing Record 6 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 6 | mogadishu
# Processing Record 8 of Set 6 | salekhard
# Processing Record 9 of Set 6 | skjervoy
# Processing Record 10 of Set 6 | bethel
# Processing Record 11 of Set 6 | parana
# Processing Record 12 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 6 | rincon
# Processing Record 14 of Set 6 | cabo san lucas
# Processing Record 15 of Set 6 | saint-joseph
# Processing Record 16 of Set 6 | labuan
# Processing Record 17 of Set 6 | katsuura
# Processing Record 18 of Set 6 | monrovia
# Processing Record 19 of Set 6 | tete
# Processing Record 20 of Set 6 | mangrol
# Processing Record 21 of Set 6 | nantucket
# Processing Record 22 of Set 6 | mimongo
# Processing Record 23 of Set 6 | kiskunlachaza
# Processing Record 24 of Set 6 | cockburn town
# Processing Record 25 of Set 6 | gombong
# Processing Record 26 of Set 6 | maua
# Processing Record 27 of Set 6 | tabou
# Processing Record 28 of Set 6 | meise
# Processing Record 29 of Set 6 | rio grande
# Processing Record 30 of Set 6 | iqaluit
# Processing Record 31 of Set 6 | camacha
# Processing Record 32 of Set 6 | pangnirtung
# Processing Record 33 of Set 6 | baracoa
# Processing Record 34 of Set 6 | kodiak
# Processing Record 35 of Set 6 | luanda
# Processing Record 36 of Set 6 | lafia
# Processing Record 37 of Set 6 | salina cruz
# Processing Record 38 of Set 6 | yeletskiy
# City not found. Skipping...
# Processing Record 39 of Set 6 | ajdabiya
# Processing Record 40 of Set 6 | vestmannaeyjar
# Processing Record 41 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 6 | dubai
# Processing Record 43 of Set 6 | pisco
# Processing Record 44 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 6 | nybro
# Processing Record 46 of Set 6 | miquelon
# Processing Record 47 of Set 6 | rafai
# Processing Record 48 of Set 6 | lagoa
# Processing Record 49 of Set 6 | souillac
# Processing Record 50 of Set 6 | sinjah
# City not found. Skipping...
# Processing Record 1 of Set 7 | naranjal
# Processing Record 2 of Set 7 | ponta do sol
# Processing Record 3 of Set 7 | fort nelson
# Processing Record 4 of Set 7 | kamenka
# Processing Record 5 of Set 7 | ahipara
# Processing Record 6 of Set 7 | montepuez
# Processing Record 7 of Set 7 | bathurst
# Processing Record 8 of Set 7 | miyako
# Processing Record 9 of Set 7 | venado tuerto
# Processing Record 10 of Set 7 | haines junction
# Processing Record 11 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 12 of Set 7 | port lincoln
# Processing Record 13 of Set 7 | canaries
# Processing Record 14 of Set 7 | sola
# Processing Record 15 of Set 7 | quatre cocos
# Processing Record 16 of Set 7 | vila
# Processing Record 17 of Set 7 | sisophon
# Processing Record 18 of Set 7 | faya
# Processing Record 19 of Set 7 | rundu
# Processing Record 20 of Set 7 | shahreza
# Processing Record 21 of Set 7 | ksenyevka
# City not found. Skipping...
# Processing Record 22 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 23 of Set 7 | odweyne
# Processing Record 24 of Set 7 | cidreira
# Processing Record 25 of Set 7 | caernarfon
# Processing Record 26 of Set 7 | hasaki
# Processing Record 27 of Set 7 | os
# City not found. Skipping...
# Processing Record 28 of Set 7 | dedougou
# Processing Record 29 of Set 7 | kharp
# Processing Record 30 of Set 7 | acapulco
# Processing Record 31 of Set 7 | riyadh
# Processing Record 32 of Set 7 | mitsamiouli
# Processing Record 33 of Set 7 | batagay-alyta
# Processing Record 34 of Set 7 | chapais
# Processing Record 35 of Set 7 | novikovo
# Processing Record 36 of Set 7 | tucurui
# Processing Record 37 of Set 7 | paso de los toros
# Processing Record 38 of Set 7 | morondava
# Processing Record 39 of Set 7 | nemuro
# Processing Record 40 of Set 7 | tashtagol
# Processing Record 41 of Set 7 | kozhva
# Processing Record 42 of Set 7 | loreto
# Processing Record 43 of Set 7 | berberati
# Processing Record 44 of Set 7 | alice springs
# Processing Record 45 of Set 7 | tezu
# Processing Record 46 of Set 7 | mar del plata
# Processing Record 47 of Set 7 | henties bay
# Processing Record 48 of Set 7 | montrose
# Processing Record 49 of Set 7 | panaba
# Processing Record 50 of Set 7 | poum
# Processing Record 1 of Set 8 | campeche
# Processing Record 2 of Set 8 | georgetown
# Processing Record 3 of Set 8 | smolyaninovo
# Processing Record 4 of Set 8 | kirkland lake
# Processing Record 5 of Set 8 | algiers
# Processing Record 6 of Set 8 | lipin bor
# Processing Record 7 of Set 8 | waw
# Processing Record 8 of Set 8 | nancha
# Processing Record 9 of Set 8 | la ronge
# Processing Record 10 of Set 8 | hay river
# Processing Record 11 of Set 8 | belturbet
# Processing Record 12 of Set 8 | sitio novo do tocantins
# Processing Record 13 of Set 8 | maxixe
# Processing Record 14 of Set 8 | luwuk
# Processing Record 15 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 8 | dongsheng
# Processing Record 17 of Set 8 | kisangani
# Processing Record 18 of Set 8 | assens
# Processing Record 19 of Set 8 | champawat
# Processing Record 20 of Set 8 | kalmunai
# Processing Record 21 of Set 8 | leningradskiy
# Processing Record 22 of Set 8 | pereira barreto
# Processing Record 23 of Set 8 | gulfport
# Processing Record 24 of Set 8 | kurilsk
# Processing Record 25 of Set 8 | dasoguz
# Processing Record 26 of Set 8 | arcata
# Processing Record 27 of Set 8 | laguna
# Processing Record 28 of Set 8 | luganville
# Processing Record 29 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 8 | jacareacanga
# Processing Record 31 of Set 8 | kadoshkino
# Processing Record 32 of Set 8 | iberia
# Processing Record 33 of Set 8 | westerly
# Processing Record 34 of Set 8 | sheltozero
# Processing Record 35 of Set 8 | kamloops
# Processing Record 36 of Set 8 | san juan
# Processing Record 37 of Set 8 | yala
# Processing Record 38 of Set 8 | eskasem
# City not found. Skipping...
# Processing Record 39 of Set 8 | auriflama
# Processing Record 40 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 41 of Set 8 | rodrigues alves
# Processing Record 42 of Set 8 | namatanai
# Processing Record 43 of Set 8 | dabakala
# Processing Record 44 of Set 8 | cieza
# Processing Record 45 of Set 8 | richards bay
# Processing Record 46 of Set 8 | humaita
# Processing Record 47 of Set 8 | road town
# Processing Record 48 of Set 8 | manta
# Processing Record 49 of Set 8 | pavilosta
# Processing Record 50 of Set 8 | nouadhibou
# Processing Record 1 of Set 9 | leh
# Processing Record 2 of Set 9 | shakawe
# Processing Record 3 of Set 9 | bourges
# Processing Record 4 of Set 9 | bakchar
# Processing Record 5 of Set 9 | laiagam
# City not found. Skipping...
# Processing Record 6 of Set 9 | isangel
# Processing Record 7 of Set 9 | biograd na moru
# Processing Record 8 of Set 9 | tanabe
# Processing Record 9 of Set 9 | xining
# Processing Record 10 of Set 9 | doha
# Processing Record 11 of Set 9 | satun
# Processing Record 12 of Set 9 | lasa
# Processing Record 13 of Set 9 | nizhniy baskunchak
# Processing Record 14 of Set 9 | taltal
# Processing Record 15 of Set 9 | santa maria
# Processing Record 16 of Set 9 | jalu
# Processing Record 17 of Set 9 | bam
# Processing Record 18 of Set 9 | troitskoye
# Processing Record 19 of Set 9 | jamkhandi
# Processing Record 20 of Set 9 | hirara
# Processing Record 21 of Set 9 | saint-augustin
# Processing Record 22 of Set 9 | kalabo
# Processing Record 23 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 24 of Set 9 | rawson
# Processing Record 25 of Set 9 | koutsouras
# Processing Record 26 of Set 9 | vyartsilya
# Processing Record 27 of Set 9 | gimli
# Processing Record 28 of Set 9 | bereda
# Processing Record 29 of Set 9 | gazanjyk
# Processing Record 30 of Set 9 | charlestown
# Processing Record 31 of Set 9 | bhadasar
# Processing Record 32 of Set 9 | karratha
# Processing Record 33 of Set 9 | grand gaube
# Processing Record 34 of Set 9 | lazaro cardenas
# Processing Record 35 of Set 9 | iquique
# Processing Record 36 of Set 9 | medea
# Processing Record 37 of Set 9 | moose factory
# Processing Record 38 of Set 9 | laurel
# Processing Record 39 of Set 9 | havre-saint-pierre
# Processing Record 40 of Set 9 | shimanovsk
# Processing Record 41 of Set 9 | mackenzie
# Processing Record 42 of Set 9 | wanaka
# Processing Record 43 of Set 9 | kloulklubed
# Processing Record 44 of Set 9 | mongo
# Processing Record 45 of Set 9 | daru
# Processing Record 46 of Set 9 | hamilton
# Processing Record 47 of Set 9 | kulhudhuffushi
# Processing Record 48 of Set 9 | sao jose da coroa grande
# Processing Record 49 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 50 of Set 9 | villarrubia de los ojos
# Processing Record 1 of Set 10 | ashland
# Processing Record 2 of Set 10 | junnar
# Processing Record 3 of Set 10 | moen
# Processing Record 4 of Set 10 | ilebo
# Processing Record 5 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 6 of Set 10 | ostrovnoy
# Processing Record 7 of Set 10 | north bend
# Processing Record 8 of Set 10 | norman wells
# Processing Record 9 of Set 10 | voronovytsya
# Processing Record 10 of Set 10 | tura
# Processing Record 11 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 12 of Set 10 | dingle
# Processing Record 13 of Set 10 | valentin gomez farias
# Processing Record 14 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 15 of Set 10 | yialos
# City not found. Skipping...
# Processing Record 16 of Set 10 | addi ugri
# City not found. Skipping...
# Processing Record 17 of Set 10 | jatiroto
# Processing Record 18 of Set 10 | shingu
# Processing Record 19 of Set 10 | gobabis
# Processing Record 20 of Set 10 | sao gabriel
# Processing Record 21 of Set 10 | coquimbo
# Processing Record 22 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 10 | margate
# Processing Record 24 of Set 10 | mount isa
# Processing Record 25 of Set 10 | freeport
# Processing Record 26 of Set 10 | brainerd
# Processing Record 27 of Set 10 | vao
# Processing Record 28 of Set 10 | kholodnyy
# Processing Record 29 of Set 10 | natchez
# Processing Record 30 of Set 10 | bundaberg
# Processing Record 31 of Set 10 | epano arkhanai
# City not found. Skipping...
# Processing Record 32 of Set 10 | sumbe
# Processing Record 33 of Set 10 | aklavik
# Processing Record 34 of Set 10 | nikolsk
# Processing Record 35 of Set 10 | jinzhou
# Processing Record 36 of Set 10 | imbituba
# Processing Record 37 of Set 10 | kirakira
# Processing Record 38 of Set 10 | nuevo progreso
# Processing Record 39 of Set 10 | sambava
# Processing Record 40 of Set 10 | kupang
# Processing Record 41 of Set 10 | kattivakkam
# Processing Record 42 of Set 10 | turayf
# Processing Record 43 of Set 10 | sao joao da barra
# Processing Record 44 of Set 10 | ojinaga
# Processing Record 45 of Set 10 | chumikan
# Processing Record 46 of Set 10 | maceio
# Processing Record 47 of Set 10 | talnakh
# Processing Record 48 of Set 10 | krasnoarmeysk
# Processing Record 49 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 50 of Set 10 | kochinda
# Processing Record 1 of Set 11 | saint-louis
# Processing Record 2 of Set 11 | berlevag
# Processing Record 3 of Set 11 | klaksvik
# Processing Record 4 of Set 11 | borba
# Processing Record 5 of Set 11 | bilma
# Processing Record 6 of Set 11 | qui nhon
# Processing Record 7 of Set 11 | codrington
# Processing Record 8 of Set 11 | halifax
# Processing Record 9 of Set 11 | tokonou
# Processing Record 10 of Set 11 | anloga
# Processing Record 11 of Set 11 | quelimane
# Processing Record 12 of Set 11 | intipuca
# Processing Record 13 of Set 11 | redlands
# Processing Record 14 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 11 | kieta
# Processing Record 16 of Set 11 | atikokan
# Processing Record 17 of Set 11 | calbuco
# Processing Record 18 of Set 11 | hambantota
# Processing Record 19 of Set 11 | aban
# Processing Record 20 of Set 11 | balkhash
# Processing Record 21 of Set 11 | rakaia
# Processing Record 22 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 23 of Set 11 | burdur
# Processing Record 24 of Set 11 | sai buri
# Processing Record 25 of Set 11 | wasilla
# Processing Record 26 of Set 11 | normandin
# Processing Record 27 of Set 11 | perth
# Processing Record 28 of Set 11 | high level
# Processing Record 29 of Set 11 | tuburan
# Processing Record 30 of Set 11 | yerbogachen
# Processing Record 31 of Set 11 | vohibinany
# Processing Record 32 of Set 11 | los llanos de aridane
# Processing Record 33 of Set 11 | kavaratti
# Processing Record 34 of Set 11 | ponoka
# Processing Record 35 of Set 11 | college
# Processing Record 36 of Set 11 | treinta y tres
# Processing Record 37 of Set 11 | plettenberg bay
# Processing Record 38 of Set 11 | banki
# Processing Record 39 of Set 11 | douentza
# Processing Record 40 of Set 11 | kibre mengist
# Processing Record 41 of Set 11 | pevek
# Processing Record 42 of Set 11 | praia
# Processing Record 43 of Set 11 | kouango
# Processing Record 44 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 45 of Set 11 | akyab
# Processing Record 46 of Set 11 | astana
# Processing Record 47 of Set 11 | najran
# Processing Record 48 of Set 11 | olafsvik
# Processing Record 49 of Set 11 | ilulissat
# Processing Record 50 of Set 11 | deputatskiy
# Processing Record 1 of Set 12 | guerrero negro
# Processing Record 2 of Set 12 | nanjing
# Processing Record 3 of Set 12 | ossora
# Processing Record 4 of Set 12 | jenks
# Processing Record 5 of Set 12 | valdemoro
# Processing Record 6 of Set 12 | duku
# Processing Record 7 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 8 of Set 12 | vardo
# Processing Record 9 of Set 12 | itacare
# Processing Record 10 of Set 12 | benguela
# Processing Record 11 of Set 12 | cah ab
# City not found. Skipping...
# Processing Record 12 of Set 12 | sakakah
# Processing Record 13 of Set 12 | beloha
# Processing Record 14 of Set 12 | khowst
# Processing Record 15 of Set 12 | paignton
# Processing Record 16 of Set 12 | harrison
# Processing Record 17 of Set 12 | winnemucca
# Processing Record 18 of Set 12 | imamoglu
# Processing Record 19 of Set 12 | tual
# Processing Record 20 of Set 12 | narayanganj
# Processing Record 21 of Set 12 | bacolod
# Processing Record 22 of Set 12 | nelson bay
# Processing Record 23 of Set 12 | portland
# Processing Record 24 of Set 12 | chilchotla
# Processing Record 25 of Set 12 | oyama
# Processing Record 26 of Set 12 | pahrump
# Processing Record 27 of Set 12 | inhambane
# Processing Record 28 of Set 12 | maragogi
# Processing Record 29 of Set 12 | wewak
# Processing Record 30 of Set 12 | gizo
# Processing Record 31 of Set 12 | sobradinho
# Processing Record 32 of Set 12 | ciudad bolivar
# Processing Record 33 of Set 12 | ishigaki
# Processing Record 34 of Set 12 | vanimo
# Processing Record 35 of Set 12 | hobyo
# Processing Record 36 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 12 | cedral
# Processing Record 38 of Set 12 | evensk
# Processing Record 39 of Set 12 | krasnyy yar
# Processing Record 40 of Set 12 | mosetse
# Processing Record 41 of Set 12 | kirkenaer
# Processing Record 42 of Set 12 | havoysund
# Processing Record 43 of Set 12 | namibe
# Processing Record 44 of Set 12 | zhigansk
# Processing Record 45 of Set 12 | chekhov
# Processing Record 46 of Set 12 | berdigestyakh
# Processing Record 47 of Set 12 | magadan
# Processing Record 48 of Set 12 | pemangkat
# Processing Record 49 of Set 12 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 12 | lerwick
# Processing Record 1 of Set 13 | ormond beach
# Processing Record 2 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 3 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 13 | callaguip
# Processing Record 5 of Set 13 | milkovo
# Processing Record 6 of Set 13 | valparaiso
# Processing Record 7 of Set 13 | lumberton
# Processing Record 8 of Set 13 | asilah
# Processing Record 9 of Set 13 | kagadi
# Processing Record 10 of Set 13 | teguldet
# Processing Record 11 of Set 13 | darhan
# Processing Record 12 of Set 13 | tres lagoas
# Processing Record 13 of Set 13 | belyy yar
# Processing Record 14 of Set 13 | kodinsk
# Processing Record 15 of Set 13 | altamont
# Processing Record 16 of Set 13 | boueni
# Processing Record 17 of Set 13 | hutchinson
# Processing Record 18 of Set 13 | port hueneme
# Processing Record 19 of Set 13 | zalantun
# Processing Record 20 of Set 13 | tomatlan
# Processing Record 21 of Set 13 | mayo
# Processing Record 22 of Set 13 | dharmadam
# Processing Record 23 of Set 13 | teya
# Processing Record 24 of Set 13 | zeya
# Processing Record 25 of Set 13 | ternate
# Processing Record 26 of Set 13 | yar-sale
# Processing Record 27 of Set 13 | puerto del rosario
# Processing Record 28 of Set 13 | jinchang
# Processing Record 29 of Set 13 | borogontsy
# Processing Record 30 of Set 13 | khash
# Processing Record 31 of Set 13 | uyuni
# Processing Record 32 of Set 13 | sungurlu
# Processing Record 33 of Set 13 | sovetskoye
# Processing Record 34 of Set 13 | iquitos
# Processing Record 35 of Set 13 | ilorin
# Processing Record 36 of Set 13 | trzcianka
# Processing Record 37 of Set 13 | arcachon
# Processing Record 38 of Set 13 | tulun
# Processing Record 39 of Set 13 | coos bay
# Processing Record 40 of Set 13 | lingsugur
# Processing Record 41 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 42 of Set 13 | mulanje
# Processing Record 43 of Set 13 | kaeo
# Processing Record 44 of Set 13 | vieques
# Processing Record 45 of Set 13 | bisho
# Processing Record 46 of Set 13 | west des moines
# Processing Record 47 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 48 of Set 13 | wajir
# Processing Record 49 of Set 13 | abu samrah
# Processing Record 50 of Set 13 | vilhena
# Processing Record 1 of Set 14 | tuatapere
# Processing Record 2 of Set 14 | vagur
# Processing Record 3 of Set 14 | bitung
# Processing Record 4 of Set 14 | solone
# Processing Record 5 of Set 14 | nishihara
# Processing Record 6 of Set 14 | waingapu
# Processing Record 7 of Set 14 | napier
# Processing Record 8 of Set 14 | homer
# Processing Record 9 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 10 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 14 | arkhangelsk
# Processing Record 12 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 14 | togur
# Processing Record 14 of Set 14 | oxapampa
# Processing Record 15 of Set 14 | praia da vitoria
# Processing Record 16 of Set 14 | umm kaddadah
# Processing Record 17 of Set 14 | curup
# Processing Record 18 of Set 14 | yumen
# Processing Record 19 of Set 14 | lumut
# Processing Record 20 of Set 14 | garmsar
# Processing Record 21 of Set 14 | mayumba
# Processing Record 22 of Set 14 | ampanihy
# Processing Record 23 of Set 14 | westport
# Processing Record 24 of Set 14 | hacari
# Processing Record 25 of Set 14 | malakal
# Processing Record 26 of Set 14 | ust-maya
# Processing Record 27 of Set 14 | langsa
# Processing Record 28 of Set 14 | coahuayana
# Processing Record 29 of Set 14 | buin
# Processing Record 30 of Set 14 | vaxjo
# Processing Record 31 of Set 14 | sorland
# Processing Record 32 of Set 14 | joshimath
# Processing Record 33 of Set 14 | la libertad
# Processing Record 34 of Set 14 | stykkisholmur
# Processing Record 35 of Set 14 | asha
# Processing Record 36 of Set 14 | oriximina
# Processing Record 37 of Set 14 | iralaya
# Processing Record 38 of Set 14 | naze
# Processing Record 39 of Set 14 | rio gallegos
# Processing Record 40 of Set 14 | nuuk
# Processing Record 41 of Set 14 | mutoko
# Processing Record 42 of Set 14 | domoni
# Processing Record 43 of Set 14 | christchurch
# Processing Record 44 of Set 14 | beringovskiy
# Processing Record 45 of Set 14 | caravelas
# Processing Record 46 of Set 14 | kaili
# Processing Record 47 of Set 14 | kjopsvik
# Processing Record 48 of Set 14 | rocha
# Processing Record 49 of Set 14 | amapa
# Processing Record 50 of Set 14 | bonthe
# Processing Record 1 of Set 15 | viransehir
# Processing Record 2 of Set 15 | port hardy
# Processing Record 3 of Set 15 | salalah
# Processing Record 4 of Set 15 | manjacaze
# Processing Record 5 of Set 15 | nadym
# Processing Record 6 of Set 15 | manicore
# Processing Record 7 of Set 15 | basco
# Processing Record 8 of Set 15 | qiongshan
# Processing Record 9 of Set 15 | andapa
# Processing Record 10 of Set 15 | sanlucar de barrameda
# Processing Record 11 of Set 15 | bjornevatn
# Processing Record 12 of Set 15 | estelle
# Processing Record 13 of Set 15 | paka
# Processing Record 14 of Set 15 | sao desiderio
# Processing Record 15 of Set 15 | sendhwa
# Processing Record 16 of Set 15 | severnyy-kospashskiy
# Processing Record 17 of Set 15 | seoul
# Processing Record 18 of Set 15 | san patricio
# Processing Record 19 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 15 | qaracala
# Processing Record 21 of Set 15 | mwense
# Processing Record 22 of Set 15 | kostrzyn
# Processing Record 23 of Set 15 | ca mau
# Processing Record 24 of Set 15 | ulaangom
# Processing Record 25 of Set 15 | rockport
# Processing Record 26 of Set 15 | hovd
# Processing Record 27 of Set 15 | huarmey
# Processing Record 28 of Set 15 | nhulunbuy
# Processing Record 29 of Set 15 | shelburne
# Processing Record 30 of Set 15 | emba
# Processing Record 31 of Set 15 | denpasar
# Processing Record 32 of Set 15 | sabha
# Processing Record 33 of Set 15 | kenai
# Processing Record 34 of Set 15 | pulsano
# Processing Record 35 of Set 15 | ahar
# Processing Record 36 of Set 15 | buritis
# Processing Record 37 of Set 15 | maneadero
# Processing Record 38 of Set 15 | dutse
# Processing Record 39 of Set 15 | mildura
# Processing Record 40 of Set 15 | boyolangu
# Processing Record 41 of Set 15 | ambon
# Processing Record 42 of Set 15 | inta
# Processing Record 43 of Set 15 | ao luk
# City not found. Skipping...
# Processing Record 44 of Set 15 | rosarito
# Processing Record 45 of Set 15 | robertsport
# Processing Record 46 of Set 15 | yarada
# Processing Record 47 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 48 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 49 of Set 15 | khorixas
# Processing Record 50 of Set 15 | launceston
# Processing Record 1 of Set 16 | guna
# Processing Record 2 of Set 16 | lampa
# Processing Record 3 of Set 16 | tucuma
# Processing Record 4 of Set 16 | acarau
# Processing Record 5 of Set 16 | wuchang
# Processing Record 6 of Set 16 | cravo norte
# Processing Record 7 of Set 16 | lusambo
# Processing Record 8 of Set 16 | magdagachi
# Processing Record 9 of Set 16 | broken hill
# Processing Record 10 of Set 16 | sechura
# Processing Record 11 of Set 16 | tongliao
# Processing Record 12 of Set 16 | muros
# Processing Record 13 of Set 16 | itanhandu
# Processing Record 14 of Set 16 | malanville
# Processing Record 15 of Set 16 | mairang
# Processing Record 16 of Set 16 | kuusamo
# Processing Record 17 of Set 16 | zhezkazgan
# Processing Record 18 of Set 16 | ozinki
# Processing Record 19 of Set 16 | den helder
# Processing Record 20 of Set 16 | una
# Processing Record 21 of Set 16 | port huron
# Processing Record 22 of Set 16 | lixourion
# Processing Record 23 of Set 16 | itoigawa
# Processing Record 24 of Set 16 | orlik
# Processing Record 25 of Set 16 | lahij
# Processing Record 26 of Set 16 | chagda
# City not found. Skipping...
# Processing Record 27 of Set 16 | solovetskiy
# City not found. Skipping...
# Processing Record 28 of Set 16 | tran
# Processing Record 29 of Set 16 | lianzhou
# Processing Record 30 of Set 16 | tecoanapa
# Processing Record 31 of Set 16 | bukama
# Processing Record 32 of Set 16 | goderich
# Processing Record 33 of Set 16 | korla
# Processing Record 34 of Set 16 | ribeira brava
# Processing Record 35 of Set 16 | maniitsoq
# Processing Record 36 of Set 16 | opuwo
# Processing Record 37 of Set 16 | fevralsk
# City not found. Skipping...
# ---------------------------
# Data Retrieval Complete
# ---------------------------

# %%
#Coverting to a Pandas DataFrame.

city_data_df = pd.DataFrame(city_data)
city_data_df.head(5)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0  Comodoro Rivadavia      AR -45.8667  -67.5000     39.06        93
# 1                Auki      SB  -8.7676  160.7034     75.78        89
# 2              Hobart      AU -42.8794  147.3294     41.05        89
# 3            Morehead      US  37.2711  -87.1764     61.00        52
# 4          Hervey Bay      AU -25.2986  152.8535     57.04        80
#
#    Cloudiness  Wind Speed Current Description
# 0          90        0.00     overcast clouds
# 1          41        3.04    scattered clouds
# 2          10        3.00           clear sky
# 3           1        1.99           clear sky
# 4          78        1.01       broken clouds

# %%
#Creating the output file
output_data_file = 'WeatherPy_Database.csv'

# %%
#Exporint the City_Data into a CSV. 

city_data_df.to_csv(output_data_file, index_label='City_ID')
